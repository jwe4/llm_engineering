# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-5-nano'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
code_fragment = input("Enter a code fragment:  ")
print(code_fragment)
# Out:
# ield from {book.get("author") for book in books if book.get("author")}

# %%
# here is the question; type over this to ask something new
print(code_fragment)

question = f"""
Please explain what this code does and why:
{code_fragment}
"""

messages = [
    {"role": "user", "content": question}
    ]

print(question)
# Out:
# ield from {book.get("author") for book in books if book.get("author")}
#
# Please explain what this code does and why:
# ield from {book.get("author") for book in books if book.get("author")}

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
# response.choices[0].message.content
display(Markdown(response.choices[0].message.content))
# Out:
# Certainly! Let's break down the code you provided:
#
# ```python
# yield from {book.get("author") for book in books if book.get("author")}
# ```
#
# ### What does this code do?
#
# 1. **Set comprehension:**
#
#    ```python
#    {book.get("author") for book in books if book.get("author")}
#    ```
#
#    This part creates a **set** of authors extracted from the `books` iterable.
#
#    - `books` is assumed to be a list (or other iterable) of dictionaries, where each dictionary represents a book.
#    - For each `book` dictionary in `books`, it uses `book.get("author")` to retrieve the `"author"` field.
#    - The `if book.get("author")` condition filters out any books where the `"author"` key is missing or evaluates to a falsy value (e.g., `None` or an empty string).
#    - Since the comprehension is inside `{}`, it creates a **set**, which keeps unique authors only (removing duplicates).
#
# 2. **`yield from`:**
#
#    ```python
#    yield from <iterable>
#    ```
#
#    The `yield from` keyword is used inside a generator function to yield all items from the given iterable one by one.
#
#    So, instead of returning the entire set, it yields authors individually.
#
# ### Why use this form?
#
# - The intent is to **yield unique authors**, one at a time, from the `books` collection.
# - Using a **set comprehension** ensures:
#   - Only unique authors are yielded (no duplicates).
#   - Authors that are `None` or missing are not included.
# - Using `yield from`:
#   - Allows these authors to be generated lazily if needed.
#   - Provides a clean and concise way to yield multiple items.
#
# ### Summary:
#
# - This code snippet, likely inside a generator function, extracts unique authors from a list of books and yields them one at a time.
# - It's an efficient way to produce unique author names without duplicates and skipping any empty or missing authors.
#
# ---
#
# If you want, I can show a full example or alternatives based on your use case.

# %%
code_fragment = input("Enter a code fragment:  ")
question = f"""
Please explain what this code does and why:
{code_fragment}
"""

messages = [
    {"role": "user", "content": question}
    ]

# %%
# Get gpt-4o-mini to answer, with streaming
stream = openai.chat.completions.create(
    model="gpt-4.1-mini",
messages = [
    {"role": "user", "content": question}
    ],
    stream=True
)    
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# Certainly! Let's break down what this code snippet does and why each part is used.
#
# ---
#
# ### Overview:
# This code snippet demonstrates how to use the OpenAI API to **stream** chat completions (like those from GPT-4) and **dynamically update the output** in a Jupyter notebook (or any IPython environment) as the response is being generated.
#
# ---
#
# ### Detailed Explanation:
#
# ```python
# stream = openai.chat.completions.create(
#     model="gpt-4.1-mini",
#     messages=[
#         {"role": "user", "content": question}
#     ],
#     stream=True
# )
# ```
# - **What it does:** Initiates a chat completion request to the OpenAI API.
# - **Parameters:**
#   - `model="gpt-4.1-mini"`: Specifies which model to use.
#   - `messages=[{"role": "user", "content": question}]`: Provides the conversation history; here it contains just a single user message stored in the variable `question`.
#   - `stream=True`: Enables streaming; instead of waiting for the entire response, the API sends partial outputs (chunks) progressively.
#
# ---
#
# ```python
# response = ""
# display_handle = display(Markdown(""), display_id=True)
# ```
# - Initializes an empty string `response` to accumulate the generated content.
# - Creates a `display_handle` that allows the program to **update a displayed Markdown cell dynamically** in the notebook. `display()` with `display_id=True` is used to create an updatable output area.
#
# ---
#
# ```python
# for chunk in stream:
#     response += chunk.choices[0].delta.content or ''
#     update_display(Markdown(response), display_id=display_handle.display_id)
# ```
# - **What it does:**
#   - Iterates over each chunk received from the API stream.
#   - Each `chunk.choices[0].delta.content` contains part of the text generated in that step.
#   - Appends the new partial content to the `response` string.
#   - Updates the displayed Markdown output **in place** with the currently accumulated response.
#
# - **Why this is useful:**
#   - This allows the user to **see the output as it is being generated rather than waiting for the full response**.
#   - It improves interactivity and responsiveness when working inside notebooks.
#
# ---
#
# ### Summary:
#
# - The whole snippet leverages OpenAI's streaming functionality to get incremental parts of the model's response.
# - It uses Jupyter notebook display utilities (`display()` and `update_display()`) to show the answer in real-time, updating the same output cell repeatedly.
# - This approach enhances the user experience by showing partial answers almost immediately and updating them as more text is generated.
#
# ---
#
# If you want, I can help you adapt this for different environments or explain any part in more detail!

# %%
# Get Llama 3.2 to answer
